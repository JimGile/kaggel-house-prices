# %%
# Imports
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.base import RegressorMixin, TransformerMixin
from sklearn.preprocessing import PowerTransformer, QuantileTransformer, StandardScaler
from sklearn.linear_model import Ridge, RidgeCV, Lasso, LassoCV, LinearRegression, ElasticNet, ElasticNetCV

from sklearn.compose import ColumnTransformer
from sklearn.ensemble import HistGradientBoostingRegressor
from sklearn.model_selection import cross_validate, KFold
from sklearn.pipeline import make_pipeline
from sklearn.model_selection import TimeSeriesSplit

# %%
# Import custom classes
from supervised_model_pipeline import EdaToolbox, RegressorMultiModelEvaluator

# %% [markdown]
# ## Inspect the data

# %%
# Load the training data
train_full_df = pd.read_csv('../data/train.csv').drop('Id', axis=1)
train_full_df.head()
# Out:
#    MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0          60       RL         65.0     8450   Pave   NaN      Reg
# 1          20       RL         80.0     9600   Pave   NaN      Reg
# 2          60       RL         68.0    11250   Pave   NaN      IR1
# 3          70       RL         60.0     9550   Pave   NaN      IR1
# 4          60       RL         84.0    14260   Pave   NaN      IR1
#
#   LandContour Utilities LotConfig  ... PoolArea PoolQC Fence MiscFeature  \
# 0         Lvl    AllPub    Inside  ...        0    NaN   NaN         NaN
# 1         Lvl    AllPub       FR2  ...        0    NaN   NaN         NaN
# 2         Lvl    AllPub    Inside  ...        0    NaN   NaN         NaN
# 3         Lvl    AllPub    Corner  ...        0    NaN   NaN         NaN
# 4         Lvl    AllPub       FR2  ...        0    NaN   NaN         NaN
#
#   MiscVal MoSold  YrSold  SaleType  SaleCondition  SalePrice
# 0       0      2    2008        WD         Normal     208500
# 1       0      5    2007        WD         Normal     181500
# 2       0      9    2008        WD         Normal     223500
# 3       0      2    2006        WD        Abnorml     140000
# 4       0     12    2008        WD         Normal     250000
#
# [5 rows x 80 columns]

# %%
# Check Square footage features to see what can be dropped
sf_features_list = ['GrLivArea', '1stFlrSF', '2ndFlrSF', 'TotalBsmtSF', 'BsmtFinSF1', 'BsmtFinSF2', 'BsmtUnfSF']
sf_df = train_full_df[sf_features_list]
print(sf_df.head())

# GrLivArea = 1stFlrSF + 2ndFlrSF
# TotalBsmtSF = BsmtFinSF1 + BsmtFinSF2 + BsmtUnfSF
# To simplify we would drop '1stFlrSF', '2ndFlrSF', 'BsmtFinSF1', 'BsmtFinSF2', 'BsmtUnfSF'
# but the accuaracy of the models is better when we drop just these 2 features
cols_to_drop = ['2ndFlrSF', 'TotalBsmtSF']
train_full_df = train_full_df.drop(cols_to_drop, axis=1)
# Out:
#    GrLivArea  1stFlrSF  2ndFlrSF  TotalBsmtSF  BsmtFinSF1  BsmtFinSF2  \
# 0       1710       856       854          856         706           0
# 1       1262      1262         0         1262         978           0
# 2       1786       920       866          920         486           0
# 3       1717       961       756          756         216           0
# 4       2198      1145      1053         1145         655           0
#
#    BsmtUnfSF
# 0        150
# 1        284
# 2        434
# 3        540
# 4        490

# %% [markdown]
# ## Create an EdaToolbox object

# %%
# Initialize the EdaToolbox
target_col = 'SalePrice'
eda = EdaToolbox(train_full_df, target_column=target_col)

# %%
# Gather initial column information sorted by data type and max value count to check for columns with high cardinality that can be pruned
col_info_df = eda.gather_initial_column_info()
col_info_df.head()
# Out:
#            data_type  max_value_count_pct most_frequent_value  unique_values  \
# Utilities     object             0.999315              AllPub              2
# Street        object             0.995890                Pave              2
# Condition2    object             0.989726                Norm              8
# RoofMatl      object             0.982192             CompShg              8
# Heating       object             0.978082                GasA              6
#
#             missing_values  missing_values_pct  \
# Utilities                0                 0.0
# Street                   0                 0.0
# Condition2               0                 0.0
# RoofMatl                 0                 0.0
# Heating                  0                 0.0
#
#                                                 top_10_values
# Utilities   Index(['AllPub', 'NoSeWa'], dtype='object', na...
# Street      Index(['Pave', 'Grvl'], dtype='object', name='...
# Condition2  Index(['Norm', 'Feedr', 'Artery', 'RRNn', 'Pos...
# RoofMatl    Index(['CompShg', 'Tar&Grv', 'WdShngl', 'WdSha...
# Heating     Index(['GasA', 'GasW', 'Grav', 'Wall', 'OthW',...

# %%
# Set pruning thresholds on the eda object according to column data type and cardinality for this dataset
eda.prune_infreq_categorical = 0.9
eda.prune_infreq_numerical = 0.95
eda.prune_pct_missing = 0.8

# Use basic ordinal feature transformer for initial investigation
eda.feature_transformer = eda.get_basic_ordinal_feature_transformer()

# %% [markdown]
# ## First check the distribution of the target column and select an appropriate target column transformer

# %%
# Plot target column distribution
eda.plot_regression_target_column_distribution()

# %%
# It is not normally distributed. It has a long tail to the right. Need to try different target transformations
target_transformation_dict: dict[str, TransformerMixin] = {
    'StandardScaler': StandardScaler(),
    'PowerTransformer': PowerTransformer(standardize=False),
    'QuantileTransformer': QuantileTransformer(output_distribution='normal', n_quantiles=500, random_state=42),
}
eda.plot_regression_target_column_distribution_variations(target_transformation_dict)

# NOTE: The PowerTransformer evenly distributes the data but not around Zero which is good for this dataset
#       because there are no negative SalePrice values.

# %%
# Create a dict of models for preliminary testing of target transformations
model_dict: dict[str, RegressorMixin] = {
    'Linear Regression': LinearRegression(),
    'Ridge Regression': Ridge(alpha=1.0, random_state=42),
    'Lasso Regression': Lasso(alpha=1.0, random_state=42),
    'ElasticNet Regression': ElasticNet(alpha=1.0, random_state=42),
    'LassoCV': LassoCV(),
    'ElasticNetCV': ElasticNetCV(),
    'RidgeCV': RidgeCV(np.logspace(-6, 6, 25)),
    'HistGradientBoost': HistGradientBoostingRegressor(max_iter=200, random_state=42)
}

# %%
# Evaluate RMSE for various regression models and target transformations with all ordinaly encoded categorical features with KFold Cross Validation
kf_cv = KFold(n_splits=5, shuffle=True, random_state=42)
model_pred_cv_df = eda.analyze_target_column_transformation_predictions(target_transformation_dict, model_dict, kf_cv)
model_pred_cv_df
# Out:
#                      Linear Regression  Ridge Regression  Lasso Regression  \
# StandardScaler                0.458296          0.457269          0.997850
# PowerTransformer              0.079379          0.058347          0.157959
# QuantileTransformer           0.369662          0.369474          1.013586
#
#                      ElasticNet Regression   LassoCV  ElasticNetCV   RidgeCV  \
# StandardScaler                    0.808411  0.438234      0.438738  0.454177
# PowerTransformer                  0.157959  0.057236      0.057223  0.057962
# QuantileTransformer               0.791327  0.362018      0.361977  0.367156
#
#                      HistGradientBoost
# StandardScaler                0.372563
# PowerTransformer              0.053401
# QuantileTransformer           0.343568

# %%
# Evaluate RMSE for various regression models and target transformations with all ordinaly encoded categorical features without CV
model_pred_df = eda.analyze_target_column_transformation_predictions(target_transformation_dict, model_dict)
model_pred_df
# Out:
#                      Linear Regression  Ridge Regression  Lasso Regression  \
# StandardScaler                0.422721          0.422694          1.103302
# PowerTransformer              0.054392          0.054367          0.171965
# QuantileTransformer           0.331671          0.331567          1.102105
#
#                      ElasticNet Regression   LassoCV  ElasticNetCV   RidgeCV  \
# StandardScaler                    0.922071  0.440283      0.439069  0.434630
# PowerTransformer                  0.171965  0.054053      0.054063  0.055202
# QuantileTransformer               0.881407  0.330971      0.332626  0.338124
#
#                      HistGradientBoost
# StandardScaler                0.362610
# PowerTransformer              0.056041
# QuantileTransformer           0.352266

# %%
# Evaluate RMSE for various regression models and target transformations with all OHE encoded categorical features
eda.feature_transformer = eda.get_basic_ohe_feature_transformer()
model_pred_cv_df = eda.analyze_target_column_transformation_predictions(target_transformation_dict, model_dict, kf_cv)
model_pred_cv_df
# Out:
#                      Linear Regression  Ridge Regression  Lasso Regression  \
# StandardScaler                0.467795          0.467634          0.997850
# PowerTransformer              0.063540          0.063519          0.157959
# QuantileTransformer           0.404040          0.403906          1.013586
#
#                      ElasticNet Regression   LassoCV  ElasticNetCV   RidgeCV  \
# StandardScaler                    0.824197  0.468194      0.468257  0.474129
# PowerTransformer                  0.157959  0.063552      0.063521  0.063579
# QuantileTransformer               0.813565  0.402884      0.402785  0.404561
#
#                      HistGradientBoost
# StandardScaler                0.396685
# PowerTransformer              0.057542
# QuantileTransformer           0.372640

# %%
# Evaluate RMSE for various regression models and target transformations with all ordinaly encoded categorical features without CV
model_pred_df = eda.analyze_target_column_transformation_predictions(target_transformation_dict, model_dict)
model_pred_df
# Out:
#                      Linear Regression  Ridge Regression  Lasso Regression  \
# StandardScaler                0.465800          0.465833          1.103302
# PowerTransformer              0.061825          0.061824          0.171965
# QuantileTransformer           0.382645          0.382669          1.102105
#
#                      ElasticNet Regression   LassoCV  ElasticNetCV   RidgeCV  \
# StandardScaler                    0.935788  0.471097      0.471597  0.470578
# PowerTransformer                  0.171965  0.063318      0.063330  0.062186
# QuantileTransformer               0.903826  0.393287      0.394578  0.386389
#
#                      HistGradientBoost
# StandardScaler                0.374671
# PowerTransformer              0.059370
# QuantileTransformer           0.384938

# %% [markdown]
# ## Set the target and feature column tranformers to the ones that performed best in the tests above
#
# * Use the PowerTransformer for the target column
# * Use the basic ordinal feature transformer

# %%
# Set target transformation and feature transformation
eda.target_transformer = PowerTransformer(standardize=False)
eda.feature_transformer = eda.get_basic_ordinal_feature_transformer()

# %% [markdown]
# ## Perform Feature Analysis

# %%
# Frist check what the correlation and coefficient numbers look like
fa_df = eda.get_regression_feature_analysis_df()
fa_df.head()
# Out:
# Best RidgeCV alpha: 100.0 (R^2 score:  0.90)
#                                     correlation_abs  coefficient_abs  \
# numerical__GrLivArea                       0.697017         0.024828
# numerical__OverallQual                     0.815044         0.027492
# ordinal_neighborhood__Neighborhood         0.740302         0.023270
# numerical__1stFlrSF                        0.593533         0.011096
# ordinal_bsmtqual__BsmtQual                 0.645938         0.006700
#
#                                         pval       vif  PCA1_abs  PCA2_abs  \
# numerical__GrLivArea                0.137808  9.454675  0.159196  0.220180
# numerical__OverallQual              0.155521  4.174746  0.223213  0.008764
# ordinal_neighborhood__Neighborhood  0.164600  3.391108  0.213725  0.009944
# numerical__1stFlrSF                 0.920492  7.289945  0.148434  0.229735
# ordinal_bsmtqual__BsmtQual          0.543016  4.274210  0.207153  0.111653
#
#                                        total
# numerical__GrLivArea                1.101222
# numerical__OverallQual              1.074513
# ordinal_neighborhood__Neighborhood  0.987241
# numerical__1stFlrSF                 0.982798
# ordinal_bsmtqual__BsmtQual          0.971444

# %%
# Plot out the highly correlated features
eda.plot_regression_feature_correlations(corr_min=0.65)

# %% [markdown]
# ## Perform unsupervised feature selection

# %%
# Try recursive feature elimination to find the optimal number of features for a linear regression model
regressor = LinearRegression()
rfecv_results_df = eda.perform_unsupervised_regression_rfe_feature_selection(regressor)
rfecv_results_df.head()
# Out:
# Optimal number of features: 28
#    mean_test_score  std_test_score  split0_test_score  split1_test_score  \
# 0        -0.008418        0.000926          -0.007919          -0.010006
# 1        -0.006968        0.000790          -0.005844          -0.007427
# 2        -0.005064        0.000590          -0.004173          -0.005446
# 3        -0.004858        0.000695          -0.003907          -0.005039
# 4        -0.004590        0.000875          -0.003385          -0.004897
#
#    split2_test_score  split3_test_score  split4_test_score  selected  ranking  \
# 0          -0.008646          -0.007211          -0.008309      True        1
# 1          -0.007505          -0.006211          -0.007853     False        2
# 2          -0.005192          -0.004658          -0.005852      True        1
# 3          -0.004957          -0.004404          -0.005981      True        1
# 4          -0.004464          -0.004167          -0.006035      True        1
#
#   feature_name
# 0   MSSubClass
# 1  LotFrontage
# 2      LotArea
# 3  OverallQual
# 4  OverallCond

# %%
rfe_lr_selected_features = eda.get_rfe_selected_features(rfecv_results_df)
print(f"RFE LR Selected Features: {rfe_lr_selected_features}")
# Out:
# RFE LR Selected Features: ['MSSubClass' 'LotArea' 'OverallQual' 'OverallCond' 'YearBuilt'
#  'BsmtFinSF1' '1stFlrSF' 'GrLivArea' 'BsmtFullBath' 'FullBath' 'HalfBath'
#  'TotRmsAbvGrd' 'GarageYrBlt' 'GarageCars' 'WoodDeckSF' 'ScreenPorch'
#  'MSZoning' 'Neighborhood' 'Condition1' 'Foundation' 'BsmtQual'
#  'BsmtExposure' 'HeatingQC' 'CentralAir' 'KitchenQual' 'Functional'
#  'FireplaceQu' 'SaleCondition']

# %%
# Try recursive feature elimination to find the optimal number of features for a RidgeCV model
regressor = RidgeCV(alphas=np.logspace(-6, 6, num=5))
rfecv_results_df = eda.perform_unsupervised_regression_rfe_feature_selection(regressor)
# Out:
# Optimal number of features: 28

# %%
rfe_ridge_selected_features = eda.get_rfe_selected_features(rfecv_results_df)
print(f"RFE Ridge Selected features: {rfe_ridge_selected_features}")
# Out:
# RFE Ridge Selected features: ['MSSubClass' 'LotArea' 'OverallQual' 'OverallCond' 'YearBuilt'
#  'BsmtFinSF1' '1stFlrSF' 'GrLivArea' 'BsmtFullBath' 'FullBath' 'HalfBath'
#  'TotRmsAbvGrd' 'GarageYrBlt' 'GarageCars' 'WoodDeckSF' 'ScreenPorch'
#  'MSZoning' 'Neighborhood' 'Condition1' 'Foundation' 'BsmtQual'
#  'BsmtExposure' 'HeatingQC' 'CentralAir' 'KitchenQual' 'Functional'
#  'FireplaceQu' 'SaleCondition']

# %%
# Try using forward SFS (SequentialFeatureSelector) to select the top 28 features
sfs_ridge_selected_features = eda.perform_unsupervised_regression_sfs_feature_selection(n_features=28)
print(f"SFS Ridge Selected Features: {sfs_ridge_selected_features}")
# Out:
# RidgeCV best alpha 1.0
# Selected 28 features by forward sequential featureselection in 20.068 seconds
# SFS Ridge Selected Features: ['MSSubClass', 'OverallQual', 'OverallCond', 'YearBuilt', 'GrLivArea', 'BsmtFullBath', 'BsmtHalfBath', 'FullBath', 'GarageCars', 'WoodDeckSF', 'EnclosedPorch', 'ScreenPorch', 'MSZoning', 'LotConfig', 'Neighborhood', 'Condition1', 'BldgType', 'Foundation', 'BsmtQual', 'BsmtExposure', 'HeatingQC', 'CentralAir', 'KitchenQual', 'Functional', 'FireplaceQu', 'GarageQual', 'PoolQC', 'SaleCondition']

# %%
# Update EDA object with selected features from RFE
eda.selected_feature_list = rfe_lr_selected_features

# Now get the list of selected ordinal columns
final_ordinal_cols = eda.get_final_ordinal_col_names(rfe_lr_selected_features)
len(final_ordinal_cols), final_ordinal_cols
# Out:
# (12,
#  ['MSZoning',
#   'Neighborhood',
#   'Condition1',
#   'Foundation',
#   'BsmtQual',
#   'BsmtExposure',
#   'HeatingQC',
#   'CentralAir',
#   'KitchenQual',
#   'Functional',
#   'FireplaceQu',
#   'SaleCondition'])

# %% [markdown]
# ## Perform final EDA with selected features and ordinal columns

# %%
# Reset transformer properties to use the selected columns and ordinal columns
eda.ordinal_encoding_col_dict = {}
for col_name in final_ordinal_cols:
    eda.add_ordinal_encoding_column(col_name, None)

eda.feature_transformer = eda.create_feature_transformer()
eda.feature_transformer
# Out:
# ColumnTransformer(transformers=[('numerical',
#                                  Pipeline(memory='named_steps',
#                                           steps=[('pruner',
#                                                   SimplePruner(infreq=0.95,
#                                                                pct_miss=0.8)),
#                                                  ('selector',
#                                                   SelectedFeaturesTransformer(selected_feature_list=array(['MSSubClass', 'LotArea', 'OverallQual', 'OverallCond', 'YearBuilt',
#        'BsmtFinSF1', '1stFlrSF', 'GrLivArea', 'BsmtFullBath', 'FullBath',
#        'HalfBath', 'TotRmsAbvGrd...
#                                                                  unknown_value=-1)),
#                                                  ('scaler', StandardScaler())]),
#                                  ['FireplaceQu']),
#                                 ('ordinal_salecondition',
#                                  Pipeline(memory='named_steps',
#                                           steps=[('SaleCondition',
#                                                   OrdinalEncoder(categories=[['AdjLand',
#                                                                               'Abnorml',
#                                                                               'Family',
#                                                                               'Alloca',
#                                                                               'Normal',
#                                                                               'Partial']],
#                                                                  encoded_missing_value=-2,
#                                                                  handle_unknown='use_encoded_value',
#                                                                  unknown_value=-1)),
#                                                  ('scaler', StandardScaler())]),
#                                  ['SaleCondition'])])

# %%
# Check feature analysis to ensure we have no multicollinearity (ie. no infinite vifs)
feature_analysis_df = eda.get_regression_feature_analysis_df()
feature_analysis_df.head()
# Out:
# Best RidgeCV alpha: 100.0 (R^2 score:  0.89)
#                                     correlation_abs  coefficient_abs  \
# numerical__GrLivArea                       0.697017         0.026887
# numerical__OverallQual                     0.815044         0.029677
# numerical__YearBuilt                       0.588037         0.006830
# numerical__TotRmsAbvGrd                    0.532020         0.010477
# ordinal_neighborhood__Neighborhood         0.740302         0.023495
#
#                                         pval       vif  PCA1_abs  PCA2_abs  \
# numerical__GrLivArea                0.074904  7.444887  0.227420  0.422616
# numerical__OverallQual              0.075554  3.656878  0.298602  0.053547
# numerical__YearBuilt                0.959676  5.479893  0.280175  0.297937
# numerical__TotRmsAbvGrd             0.810805  3.486635  0.169440  0.423420
# ordinal_neighborhood__Neighborhood  0.093168  3.106307  0.288618  0.067208
#
#                                        total
# numerical__GrLivArea                1.373941
# numerical__OverallQual              1.196870
# numerical__YearBuilt                1.172979
# numerical__TotRmsAbvGrd             1.135357
# ordinal_neighborhood__Neighborhood  1.119623

# %%
eda.plot_important_features(feature_analysis_df)

# %% [markdown]
# # Now do model analysis for multiple regression models

# %%
# Reload the data just to be safe
train_full_df = pd.read_csv('../data/train.csv')

# Create an instance of RegressorMultiModelEvaluator and set various properties
reg = RegressorMultiModelEvaluator(train_full_df, target_column='SalePrice')
reg.set_column_transformer_properties(selected_feature_list=eda.selected_feature_list, ordinal_feature_list=final_ordinal_cols)
reg.set_target_column_transformer(eda.target_transformer)

# %%
# Create a dict of models to test
model_dict: dict[str, RegressorMixin] = {
    'Linear Regression': LinearRegression(),
    'Ridge Regression': Ridge(alpha=1.0, random_state=42),
    # 'LassoCV': LassoCV(),
    # 'ElasticNetCV': ElasticNetCV(),
    # 'RidgeCV': RidgeCV(alphas=np.logspace(-6, 6, num=7)),
    'HistGradientBoost': HistGradientBoostingRegressor(max_iter=200, random_state=42)
}

# %%
# Evaluate the models
eval_df = reg.evaluate_models(model_dict)
eval_df
# Out:
# Number original X cols: 80
# Number scaled X cols: 28
#                    train_r2       mse        r2    r2_adj  lr_cv_mean  \
# model_name
# Linear Regression  0.887244  0.002713  0.907679  0.897850    0.887643
# Ridge Regression   0.887243  0.002713  0.907665  0.897834    0.887643
# HistGradientBoost  0.994176  0.003135  0.893315  0.881957    0.887643
#
#                    lr_cv_std      time  \
# model_name
# Linear Regression   0.044342  0.017183
# Ridge Regression    0.044342  0.015176
# HistGradientBoost   0.044342  0.548074
#
#                                                               y_pred
# model_name
# Linear Regression  [7.764342838650248, 8.109340052947646, 7.70170...
# Ridge Regression   [7.7643166377887844, 8.109230316882835, 7.7017...
# HistGradientBoost  [7.752941314418586, 8.129863987262882, 7.66005...

# %%
reg.plot_model_evaluations()

# %%
# Get the best model
reg.best_model_name
# Out:
# 'Linear Regression'

# %% [markdown]
# ## Now use the best model to predict on the test data

# %%
# Load test data
test_full_df = pd.read_csv('../data/test.csv')
test_full_df.head()
# Out:
#      Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0  1461          20       RH         80.0    11622   Pave   NaN      Reg
# 1  1462          20       RL         81.0    14267   Pave   NaN      IR1
# 2  1463          60       RL         74.0    13830   Pave   NaN      IR1
# 3  1464          60       RL         78.0     9978   Pave   NaN      IR1
# 4  1465         120       RL         43.0     5005   Pave   NaN      IR1
#
#   LandContour Utilities  ... ScreenPorch PoolArea PoolQC  Fence MiscFeature  \
# 0         Lvl    AllPub  ...         120        0    NaN  MnPrv         NaN
# 1         Lvl    AllPub  ...           0        0    NaN    NaN        Gar2
# 2         Lvl    AllPub  ...           0        0    NaN  MnPrv         NaN
# 3         Lvl    AllPub  ...           0        0    NaN    NaN         NaN
# 4         HLS    AllPub  ...         144        0    NaN    NaN         NaN
#
#   MiscVal MoSold  YrSold  SaleType  SaleCondition
# 0       0      6    2010        WD         Normal
# 1   12500      6    2010        WD         Normal
# 2       0      3    2010        WD         Normal
# 3       0      6    2010        WD         Normal
# 4       0      1    2010        WD         Normal
#
# [5 rows x 80 columns]

# %%
# Make predictions with LR
reg.best_model = model_dict['Linear Regression']
lr_predictions = reg.predict(test_full_df)
lr_predictions
# Out:
# array([117903.94137309, 151779.44876501, 173317.75081156, ...,
#        167187.58329172, 118806.9324089 , 231357.98740887])

# %%
# Prepare submission file for LR
new_submission_df = pd.DataFrame({
    'Id': test_full_df['Id'],
    'SalePrice': lr_predictions
})
new_submission_df.to_csv('../data/new_submission_lr.csv', index=False)
new_submission_df
# Out:
#         Id      SalePrice
# 0     1461  117903.941373
# 1     1462  151779.448765
# 2     1463  173317.750812
# 3     1464  198485.213610
# 4     1465  194771.509742
# ...    ...            ...
# 1454  2915   91966.143735
# 1455  2916   85799.363287
# 1456  2917  167187.583292
# 1457  2918  118806.932409
# 1458  2919  231357.987409
#
# [1459 rows x 2 columns]

# %%
# Make predictions with Ridge Regression
reg.best_model = model_dict['Ridge Regression']
rr_predictions = reg.predict(test_full_df)
rr_predictions
# Out:
# array([117906.13959767, 151821.34985512, 173338.07028053, ...,
#        167214.46529946, 118826.11057491, 231368.63127176])

# %%
# Prepare submission file for RR
new_submission_df = pd.DataFrame({
    'Id': test_full_df['Id'],
    'SalePrice': rr_predictions
})
new_submission_df.to_csv('../data/new_submission_rr.csv', index=False)
new_submission_df
# Out:
#         Id      SalePrice
# 0     1461  117906.139598
# 1     1462  151821.349855
# 2     1463  173338.070281
# 3     1464  198520.079567
# 4     1465  194765.811713
# ...    ...            ...
# 1454  2915   91975.346534
# 1455  2916   85824.128074
# 1456  2917  167214.465299
# 1457  2918  118826.110575
# 1458  2919  231368.631272
#
# [1459 rows x 2 columns]

# %%
# Make predictions with HistGradientBoost
reg.best_model = model_dict['HistGradientBoost']
hgb_predictions = reg.predict(test_full_df)
hgb_predictions
# Out:
# array([124451.54786276, 165622.31880776, 192125.97481691, ...,
#        153984.02621386, 124882.86718913, 221384.83925466])

# %%
# Prepare submission file for HGB
new_submission_df = pd.DataFrame({
    'Id': test_full_df['Id'],
    'SalePrice': hgb_predictions
})
new_submission_df.to_csv('../data/new_submission_hgb.csv', index=False)
new_submission_df
# Out:
#         Id      SalePrice
# 0     1461  124451.547863
# 1     1462  165622.318808
# 2     1463  192125.974817
# 3     1464  192089.676984
# 4     1465  195406.206153
# ...    ...            ...
# 1454  2915   83281.160124
# 1455  2916   86385.135385
# 1456  2917  153984.026214
# 1457  2918  124882.867189
# 1458  2919  221384.839255
#
# [1459 rows x 2 columns]
